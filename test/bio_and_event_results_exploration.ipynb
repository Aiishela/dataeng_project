# %%
# --- Olympic Data Cleaning Notebook ---
# This notebook contains all steps to clean the Olympic Bio and Event Result datasets.

import pandas as pd
import numpy as np
from pathlib import Path
import unicodedata
import json

# ============================
# 1. LOAD RAW DATA
# ============================
# Adjust paths to your docker/airflow layout
landing = Path("../data/olympic")

bio = pd.read_csv(landing /"Olympic_Athlete_Bio.csv")
res = pd.read_csv(landing /"Olympic_Athlete_Event_Results.csv")
cou = pd.read_csv(landing /"Olympics_Country.csv")

print("Bio rows:", len(bio))
print("Results rows:", len(res))
print("Results rows:", len(cou))

# ============================
# 2. INITIAL EXPLORATION
# ============================
print("\n--- BIO Missing Values ---")
print(bio.isna().sum())

print("\n--- RESULTS Missing Values ---")
print(res.isna().sum())


print("\n--- COUNTRIES Missing Values ---")
print(cou.isna().sum())
# Out:
# Bio rows: 155861
# Results rows: 316834
# Results rows: 235
#
# --- BIO Missing Values ---
# athlete_id            0
# name                  0
# sex                   0
# born               4053
# height            50749
# weight            50749
# country               0
# country_noc           0
# description      100998
# special_notes     95224
# dtype: int64
#
# --- RESULTS Missing Values ---
# edition             0
# edition_id          0
# country_noc         0
# sport               0
# event               0
# result_id           0
# athlete             0
# athlete_id          0
# pos                 0
# medal          272147
# isTeamSport         0
# dtype: int64
#
# --- COUNTRIES Missing Values ---
# noc        0
# country    0
# dtype: int64

# %%
len(res[['edition','edition_id']].drop_duplicates())
# Out:
# 55

# %%
# ============================
# 3. CLEANING: ATHLETE BIO
# ============================

# --- ID Cleaning ---
bio['athlete_id'] = pd.to_numeric(bio['athlete_id'], errors='coerce')
bio = bio.drop_duplicates(subset=['athlete_id'], keep='first')
print("Bio rows:", len(bio))

dupes = cou[cou.duplicated(subset=['noc'], keep=False)]
print(dupes)
# Out:
# Bio rows: 155861
#      noc                    country
# 169  ROC                        ROC
# 234  ROC  Russian Olympic Committee

# %%
cou = cou[~((cou['noc'] == 'ROC') & (cou['country'] == 'ROC'))]
dupes = cou[cou.duplicated(subset=['noc'], keep=False)]
print(dupes)
# Out:
# Empty DataFrame
# Columns: [noc, country]
# Index: []

# %%
dupes = cou[cou.duplicated(subset=['country'], keep=False)]
print(dupes)
# Out:
# Empty DataFrame
# Columns: [noc, country]
# Index: []

# %%
cou['country'] = cou['country'].astype(str).str.strip().str.upper()
countries = set(cou['country'].dropna().unique())
bio['country'] = bio['country'].astype(str).str.strip().str.upper()

orphaned = bio[~bio['country'].isin(countries)]
print("\nOrphaned country rows:", len(orphaned))
orphaned.head()
# Out:
# Orphaned country rows: 2544
#      athlete_id                name     sex              born  height weight  \
# 5        146111  Svetlana Kholomina  Female   9 November 1997     NaN    NaN
# 28        24775      Fathi Khorshid    Male  11 December 1937     NaN    NaN
# 49         2821     Ilija Lupulesku    Male   30 October 1967   177.0     79
# 53        37731         Birte Siech  Female     19 March 1967   180.0     75
# 103       81801  Lucia Medzihradská  Female  14 November 1968     NaN    NaN
#
#                                                country country_noc  \
# 5                                                  ROC         ROC
# 28                         EGYPT  UNITED ARAB REPUBLIC         EGY
# 49   INDEPENDENT OLYMPIC ATHLETES  SERBIA AND MONTE...         IOA
# 53                               EAST GERMANY  GERMANY         GDR
# 103                           CZECHOSLOVAKIA  SLOVAKIA         TCH
#
#                                            description  \
# 5                                                  NaN
# 28   Growing up in the agricultural town of El Maha...
# 49                                                 NaN
# 53   Rower Birte Siech won the gold medal with the ...
# 103                                                NaN
#
#                                          special_notes
# 5                                                  NaN
# 28   Listed in Olympians Who Participated in the 19...
# 49   Husband (divorced) of Jasna Fazlić-Reed Listed...
# 53                                                 NaN
# 103                                                NaN

# %%
cou['noc'] = cou['noc'].astype(str).str.strip().str.upper()
country_nocs = set(cou['noc'].dropna().unique())
bio['country_noc'] = bio['country_noc'].astype(str).str.strip().str.upper()

orphaned = bio[~bio['country_noc'].isin(country_nocs)]
print("\nOrphaned country rows:", len(orphaned))
orphaned.head()
# Out:
# Orphaned country rows: 2
#         athlete_id              name   sex            born  height weight  \
# 9910         97272  Helmuth Schmalzl  Male  8 October 1948   183.0     74
# 153046       97014    Bernhard Russi  Male  20 August 1948   182.0     71
#
#                                                   country country_noc  \
# 9910       International Federation Representative  Italy         IFR
# 153046   International Federation Representative  Swit...         IFR
#
#                                               description  \
# 9910                                                  NaN
# 153046  Bernhard Russi claims to have taken up skiing ...
#
#                                             special_notes
# 9910                          Cousin of Eberardo Schmalzl
# 153046  Listed in Olympians Involved in James Bond mov...

# %%
cou = pd.concat([cou, pd.DataFrame([{'noc': 'IFR', 'country': 'International Federation Representative Italy'}])], ignore_index=True)
cou['noc'] = cou['noc'].astype(str).str.strip().str.upper()
country_nocs = set(cou['noc'].dropna().unique())
bio['country_noc'] = bio['country_noc'].astype(str).str.strip().str.upper()

orphaned = bio[~bio['country_noc'].isin(country_nocs)]
print("\nOrphaned country rows:", len(orphaned))
orphaned.head()
# Out:
# Orphaned country rows: 0
# Empty DataFrame
# Columns: [athlete_id, name, sex, born, height, weight, country, country_noc, description, special_notes]
# Index: []

# %%
cou['noc'] = cou['noc'].astype(str).str.strip().str.upper()
country_nocs = set(cou['noc'].dropna().unique())
res['country_noc'] = res['country_noc'].astype(str).str.strip().str.upper()

orphaned = res[~res['country_noc'].isin(country_nocs)]
print("\nOrphaned country rows:", len(orphaned))
orphaned.head()
# Out:
# Orphaned country rows: 0
# Empty DataFrame
# Columns: [edition, edition_id, country_noc, sport, event, result_id, athlete, athlete_id, pos, medal, isTeamSport]
# Index: []

# %%
# --- Name Normalization ---
bio['name'] = bio['name'].astype(str).str.strip()
bio['name_norm'] = bio['name'].apply(lambda s: unicodedata.normalize('NFKC', s))

# --- Sex Normalization ---
bio['sex'] = bio['sex'].astype(str).str.upper().str.strip().replace({'Male':'M','Female':'F'})


# ============================
# 4. CLEANING: EVENT RESULTS
# ============================

# --- Convert numeric IDs ---
res['athlete_id'] = pd.to_numeric(res['athlete_id'], errors='coerce')
res['edition_id'] = pd.to_numeric(res['edition_id'], errors='coerce')

# --- Medal Normalization ---
res['medal'] = res['medal'].astype(str).str.strip()
res['medal'] = res['medal'].replace({'': None, 'nan': None})


# --- Remove Invalid Edition Years ---


# ============================
# 5. RELATIONSHIP CHECKS
# ============================
ath_ids = set(bio['athlete_id'].dropna().astype(int).unique())
res['athlete_id'] = pd.to_numeric(res['athlete_id'], errors='coerce')

orphaned = res[~res['athlete_id'].isin(ath_ids)]
print("\nOrphaned Results Rows:", len(orphaned))
# Out:
# Orphaned Results Rows: 0

# %%
# Drop columns from Olympic Bio
bio = bio.drop(columns=['born', 'height', 'weight', 'country', 'description', 'special_notes'])

# Drop columns from Olympic Event Results
res = res.drop(columns=['athlete', 'pos', 'isTeamSport'])

# Check the result
print("Bio columns:", bio.columns)
print("Results columns:", res.columns)
# Out:
# Bio columns: Index(['athlete_id', 'name', 'sex', 'country_noc'], dtype='object')
# Results columns: Index(['edition', 'edition_id', 'country_noc', 'sport', 'event', 'result_id',
#        'athlete_id', 'medal'],
#       dtype='object')

# %%
# ============================
# 6. SAVE CLEANED DATA
# ============================
staging = Path("../test/cleaned")
staging.mkdir(parents=True, exist_ok=True)


# Save cleaned datasets as CSV instead of Parquet
bio.to_csv(staging / "Olympic_Athlete_Bio.csv", index=False)
res.to_csv(staging / "Olympic_Athlete_Event_Results.csv", index=False)
cou.to_csv(staging / "Olympics_Country.csv", index=False)


print("\nCleaning completed. Cleaned files saved to staging.")
# Out:
# Cleaning completed. Cleaned files saved to staging.

# %%
# --- Olympic Data Cleaning Notebook ---
# This notebook contains all steps to clean the Olympic Bio and Event Result datasets.

import pandas as pd
import numpy as np
from pathlib import Path
import unicodedata
import json

# ============================
# 1. LOAD RAW DATA
# ============================
# Adjust paths to your docker/airflow layout
landing = Path("../data/landing")

games = pd.read_csv(landing /"Olympics_Games.csv")


print("Bio rows:", len(games))


# ============================
# 2. INITIAL EXPLORATION
# ============================
print("\n--- GAMES Missing Values ---")
print(games.isna().sum())
# Out:
# Bio rows: 64
#
# --- GAMES Missing Values ---
# edition              0
# edition_id           0
# edition_url          0
# year                 0
# city                 0
# country_flag_url     0
# country_noc          0
# start_date           9
# end_date            10
# competition_date     0
# isHeld              59
# dtype: int64

# %%
# Step 1: Split by EN DASH
split_dates = games['competition_date'].str.split('–', expand=True)
start = split_dates[0].str.strip()
end = split_dates[1].str.strip()

# Step 2: Extract day and month from start
games['start_day'] = start.str.extract(r'(\d+)')  # digits
games['start_month'] = start.str.extract(r'([A-Za-z]+)')  # letters

# Step 3: Extract day and month from end
games['end_day'] = end.str.extract(r'(\d+)')
games['end_month'] = end.str.extract(r'([A-Za-z]+)')

# Step 4: Fill missing start_month with end_month
games['start_month'] = games['start_month'].fillna(games['end_month'])

# Optional: convert to integers for day
games['start_day'] = games['start_day'].astype(int)
games['end_day'] = games['end_day'].astype(int)

print(games[['start_day','start_month','end_day','end_month','competition_date']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 18
#      15 games['start_month'] = games['start_month'].fillna(games['end_month'])
#      17 # Optional: convert to integers for day
# ---> 18 games['start_day'] = games['start_day'].astype(int)
#      19 games['end_day'] = games['end_day'].astype(int)
#      21 print(games[['start_day','start_month','end_day','end_month','competition_date']])
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/internals/blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer

# %%
games=games[games['competition_date']!='—']

# %%
# Step 1: Split by EN DASH
split_dates = games['competition_date'].str.split('–', expand=True)
start = split_dates[0].str.strip()
end = split_dates[1].str.strip()

# Step 2: Extract day and month from start
games['start_day'] = start.str.extract(r'(\d+)')  # digits
games['start_month'] = start.str.extract(r'([A-Za-z]+)')  # letters

# Step 3: Extract day and month from end
games['end_day'] = end.str.extract(r'(\d+)')
games['end_month'] = end.str.extract(r'([A-Za-z]+)')

# Step 4: Fill missing start_month with end_month
games['start_month'] = games['start_month'].fillna(games['end_month'])

# Optional: convert to integers for day
games['start_day'] = games['start_day'].astype(int)
games['end_day'] = games['end_day'].astype(int)

print(games[['start_day','start_month','end_day','end_month','competition_date']])
# Out:
#     start_day start_month  end_day  end_month           competition_date
# 0           6       April       13      April               6 – 13 April
# 1          14         May       28    October        14 May – 28 October
# 2           1        July       26   November       1 July – 26 November
# 3          27       April       31    October      27 April – 31 October
# 4           5         May       27       July            5 May – 27 July
# 6          23       April       12  September    23 April – 12 September
# 7           4         May       27       July            4 May – 27 July
# 8          17         May       12     August         17 May – 12 August
# 9          30        July       14     August        30 July – 14 August
# 10          1      August       16     August              1 – 16 August
# 13         26        July       14     August        26 July – 14 August
# 14         14        July        3     August        14 July –  3 August
# 15         22    November        8   December  22 November –  8 December
# 16         25      August       11  September   25 August – 11 September
# 17         11     October       24    October            11 – 24 October
# 18         12     October       27    October            12 – 27 October
# 19         26      August       11  September   26 August – 11 September
# 20         18        July        1     August        18 July –  1 August
# 21         20        July        3     August        20 July –  3 August
# 22          6        July       12     August         6 July – 12 August
# 23         17   September        2    October  17 September –  2 October
# 24         24        July        9     August        24 July –  9 August
# 25         20        July        4     August        20 July –  4 August
# 26         13   September        1    October  13 September –  1 October
# 27         11      August       29     August             11 – 29 August
# 28          6      August       24     August              6 – 24 August
# 29         25        July       12     August        25 July – 12 August
# 30          3      August       21     August              3 – 21 August
# 31         21        July        8     August   21 July –  8 August 2021
# 35         26     January        4   February   26 January –  4 February
# 36         11    February       19   February           11 – 19 February
# 37          4    February       15   February            4 – 15 February
# 38          6    February       16   February            6 – 16 February
# 41         30     January        8   February   30 January –  8 February
# 42         14    February       25   February           14 – 25 February
# 43         26     January        5   February   26 January –  5 February
# 44         19    February       28   February           19 – 28 February
# 45         27     January        9   February   27 January –  9 February
# 46          4    February       18   February            4 – 18 February
# 47          3    February       13   February            3 – 13 February
# 48          3    February       15   February            3 – 15 February
# 49         12    February       24   February           12 – 24 February
# 50          7    February       19   February            7 – 19 February
# 51         13    February       28   February           13 – 28 February
# 52          8    February       23   February            8 – 23 February
# 53         12    February       27   February           12 – 27 February
# 54          7    February       22   February            7 – 22 February
# 55          9    February       24   February            9 – 24 February
# 56         11    February       26   February           11 – 26 February
# 57         12    February       28   February           12 – 28 February
# 58          6    February       23   February            6 – 23 February
# 59          8    February       25   February            8 – 25 February
# 60          2    February       20   February            2 – 20 February
# 61          4    February       22   February            4 – 22 February
# 62         11        June       17       June               11 – 17 June
# 63         22       April        2        May          22 April –  2 May

# %%
games['start_month_num'] = pd.to_datetime(games['start_month'], format='%B').dt.month
games['end_month_num'] = pd.to_datetime(games['end_month'], format='%B').dt.month
print(games[['start_month','start_month_num','end_month','end_month_num']])
# Out:
#    start_month  start_month_num  end_month  end_month_num
# 0        April                4      April              4
# 1          May                5    October             10
# 2         July                7   November             11
# 3        April                4    October             10
# 4          May                5       July              7
# 6        April                4  September              9
# 7          May                5       July              7
# 8          May                5     August              8
# 9         July                7     August              8
# 10      August                8     August              8
# 13        July                7     August              8
# 14        July                7     August              8
# 15    November               11   December             12
# 16      August                8  September              9
# 17     October               10    October             10
# 18     October               10    October             10
# 19      August                8  September              9
# 20        July                7     August              8
# 21        July                7     August              8
# 22        July                7     August              8
# 23   September                9    October             10
# 24        July                7     August              8
# 25        July                7     August              8
# 26   September                9    October             10
# 27      August                8     August              8
# 28      August                8     August              8
# 29        July                7     August              8
# 30      August                8     August              8
# 31        July                7     August              8
# 35     January                1   February              2
# 36    February                2   February              2
# 37    February                2   February              2
# 38    February                2   February              2
# 41     January                1   February              2
# 42    February                2   February              2
# 43     January                1   February              2
# 44    February                2   February              2
# 45     January                1   February              2
# 46    February                2   February              2
# 47    February                2   February              2
# 48    February                2   February              2
# 49    February                2   February              2
# 50    February                2   February              2
# 51    February                2   February              2
# 52    February                2   February              2
# 53    February                2   February              2
# 54    February                2   February              2
# 55    February                2   February              2
# 56    February                2   February              2
# 57    February                2   February              2
# 58    February                2   February              2
# 59    February                2   February              2
# 60    February                2   February              2
# 61    February                2   February              2
# 62        June                6       June              6
# 63       April                4        May              5

# %%
games['competition_start_date'] = pd.to_datetime(
    dict(year=games['year'],
         month=games['start_month_num'],
         day=games['start_day'])
)

games['competition_end_date'] = pd.to_datetime(
    dict(year=games['year'],
         month=games['end_month_num'],
         day=games['end_day'])
)

# Check result
print(games[['competition_start_date','competition_end_date','competition_date','year']])
# Out:
#    competition_start_date competition_end_date           competition_date  \
# 0              1896-04-06           1896-04-13               6 – 13 April
# 1              1900-05-14           1900-10-28        14 May – 28 October
# 2              1904-07-01           1904-11-26       1 July – 26 November
# 3              1908-04-27           1908-10-31      27 April – 31 October
# 4              1912-05-05           1912-07-27            5 May – 27 July
# 6              1920-04-23           1920-09-12    23 April – 12 September
# 7              1924-05-04           1924-07-27            4 May – 27 July
# 8              1928-05-17           1928-08-12         17 May – 12 August
# 9              1932-07-30           1932-08-14        30 July – 14 August
# 10             1936-08-01           1936-08-16              1 – 16 August
# 13             1948-07-26           1948-08-14        26 July – 14 August
# 14             1952-07-14           1952-08-03        14 July –  3 August
# 15             1956-11-22           1956-12-08  22 November –  8 December
# 16             1960-08-25           1960-09-11   25 August – 11 September
# 17             1964-10-11           1964-10-24            11 – 24 October
# 18             1968-10-12           1968-10-27            12 – 27 October
# 19             1972-08-26           1972-09-11   26 August – 11 September
# 20             1976-07-18           1976-08-01        18 July –  1 August
# 21             1980-07-20           1980-08-03        20 July –  3 August
# 22             1984-07-06           1984-08-12         6 July – 12 August
# 23             1988-09-17           1988-10-02  17 September –  2 October
# 24             1992-07-24           1992-08-09        24 July –  9 August
# 25             1996-07-20           1996-08-04        20 July –  4 August
# 26             2000-09-13           2000-10-01  13 September –  1 October
# 27             2004-08-11           2004-08-29             11 – 29 August
# 28             2008-08-06           2008-08-24              6 – 24 August
# 29             2012-07-25           2012-08-12        25 July – 12 August
# 30             2016-08-03           2016-08-21              3 – 21 August
# 31             2020-07-21           2020-08-08   21 July –  8 August 2021
# 35             1924-01-26           1924-02-04   26 January –  4 February
# 36             1928-02-11           1928-02-19           11 – 19 February
# 37             1932-02-04           1932-02-15            4 – 15 February
# 38             1936-02-06           1936-02-16            6 – 16 February
# 41             1948-01-30           1948-02-08   30 January –  8 February
# 42             1952-02-14           1952-02-25           14 – 25 February
# 43             1956-01-26           1956-02-05   26 January –  5 February
# 44             1960-02-19           1960-02-28           19 – 28 February
# 45             1964-01-27           1964-02-09   27 January –  9 February
# 46             1968-02-04           1968-02-18            4 – 18 February
# 47             1972-02-03           1972-02-13            3 – 13 February
# 48             1976-02-03           1976-02-15            3 – 15 February
# 49             1980-02-12           1980-02-24           12 – 24 February
# 50             1984-02-07           1984-02-19            7 – 19 February
# 51             1988-02-13           1988-02-28           13 – 28 February
# 52             1992-02-08           1992-02-23            8 – 23 February
# 53             1994-02-12           1994-02-27           12 – 27 February
# 54             1998-02-07           1998-02-22            7 – 22 February
# 55             2002-02-09           2002-02-24            9 – 24 February
# 56             2006-02-11           2006-02-26           11 – 26 February
# 57             2010-02-12           2010-02-28           12 – 28 February
# 58             2014-02-06           2014-02-23            6 – 23 February
# 59             2018-02-08           2018-02-25            8 – 25 February
# 60             2022-02-02           2022-02-20            2 – 20 February
# 61             2026-02-04           2026-02-22            4 – 22 February
# 62             1956-06-11           1956-06-17               11 – 17 June
# 63             1906-04-22           1906-05-02          22 April –  2 May
#
#     year
# 0   1896
# 1   1900
# 2   1904
# 3   1908
# 4   1912
# 6   1920
# 7   1924
# 8   1928
# 9   1932
# 10  1936
# 13  1948
# 14  1952
# 15  1956
# 16  1960
# 17  1964
# 18  1968
# 19  1972
# 20  1976
# 21  1980
# 22  1984
# 23  1988
# 24  1992
# 25  1996
# 26  2000
# 27  2004
# 28  2008
# 29  2012
# 30  2016
# 31  2020
# 35  1924
# 36  1928
# 37  1932
# 38  1936
# 41  1948
# 42  1952
# 43  1956
# 44  1960
# 45  1964
# 46  1968
# 47  1972
# 48  1976
# 49  1980
# 50  1984
# 51  1988
# 52  1992
# 53  1994
# 54  1998
# 55  2002
# 56  2006
# 57  2010
# 58  2014
# 59  2018
# 60  2022
# 61  2026
# 62  1956
# 63  1906

# %%
print(games.isna().sum())
# Out:
# edition                    0
# edition_id                 0
# edition_url                0
# year                       0
# city                       0
# country_flag_url           0
# country_noc                0
# start_date                 1
# end_date                   2
# competition_date           0
# isHeld                    56
# start_day                  0
# start_month                0
# end_day                    0
# end_month                  0
# start_month_num            0
# end_month_num              0
# competition_start_date     0
# competition_end_date       0
# dtype: int64

# %%
games['start_month_num'] = pd.to_datetime(games['start_month'], format='%B').dt.month
games['end_month_num'] = pd.to_datetime(games['end_month'], format='%B').dt.month
print(games[['start_month','start_month_num','end_month','end_month_num']])
# Out:
#    start_month  start_month_num  end_month  end_month_num
# 0        April                4      April              4
# 1          May                5    October             10
# 2         July                7   November             11
# 3        April                4    October             10
# 4          May                5       July              7
# 6        April                4  September              9
# 7          May                5       July              7
# 8          May                5     August              8
# 9         July                7     August              8
# 10      August                8     August              8
# 13        July                7     August              8
# 14        July                7     August              8
# 15    November               11   December             12
# 16      August                8  September              9
# 17     October               10    October             10
# 18     October               10    October             10
# 19      August                8  September              9
# 20        July                7     August              8
# 21        July                7     August              8
# 22        July                7     August              8
# 23   September                9    October             10
# 24        July                7     August              8
# 25        July                7     August              8
# 26   September                9    October             10
# 27      August                8     August              8
# 28      August                8     August              8
# 29        July                7     August              8
# 30      August                8     August              8
# 31        July                7     August              8
# 35     January                1   February              2
# 36    February                2   February              2
# 37    February                2   February              2
# 38    February                2   February              2
# 41     January                1   February              2
# 42    February                2   February              2
# 43     January                1   February              2
# 44    February                2   February              2
# 45     January                1   February              2
# 46    February                2   February              2
# 47    February                2   February              2
# 48    February                2   February              2
# 49    February                2   February              2
# 50    February                2   February              2
# 51    February                2   February              2
# 52    February                2   February              2
# 53    February                2   February              2
# 54    February                2   February              2
# 55    February                2   February              2
# 56    February                2   February              2
# 57    February                2   February              2
# 58    February                2   February              2
# 59    February                2   February              2
# 60    February                2   February              2
# 61    February                2   February              2
# 62        June                6       June              6
# 63       April                4        May              5

# %%
games = games.drop(columns=['edition', 'edition_url', 'year', 'city', 'start_date','end_date','start_day','end_day','isHeld','start_month','end_month','start_month_num','end_month_num','competition_date','country_flag_url'])
staging = Path("../test/cleaned")
staging.mkdir(parents=True, exist_ok=True)


# Save cleaned datasets as CSV instead of Parquet
games.to_csv(staging / "Olympics_Games.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 7
#       3 staging.mkdir(parents=True, exist_ok=True)
#       6 # Save cleaned datasets as CSV instead of Parquet
# ----> 7 bio.to_csv(staging / "Olympics_Games.csv", index=False)
#
# NameError: name 'bio' is not defined

# %%
games.to_csv(staging / "Olympics_Games.csv", index=False)

# %%
print(games.isna().sum())
# Out:
# edition_id                0
# country_noc               0
# competition_start_date    0
# competition_end_date      0
# dtype: int64
