# %%
import pandas as pd
import numpy as np
from pathlib import Path
import unicodedata
import json

# ============================
# 1. LOAD RAW DATA
# ============================
# Adjust paths to your docker/airflow layout
staging = Path("../data/staging")


cou = pd.read_csv(staging /"Olympics_Country.csv")
nd = pd.read_csv(staging /"02_normalize_date.csv")
print(len(cou))
print(len(nd['Country'].drop_duplicates()))
# Out:
# 235
# 231

# %%
in_countries = nd[nd['Country'].str.lower().isin(cou['country'].str.lower())]
len(in_countries['Country'].drop_duplicates())
# Out:
# 186

# %%
not_in_countries = nd[
    ~nd['Country'].str.lower().isin(cou['country'].str.lower())
]
len(not_in_countries['Country'].drop_duplicates())
# Out:
# 45

# %%
print(not_in_countries['Country'].drop_duplicates())
# Out:
# 2                                                   Gambia
# 9                                      Yemen Arab Republic
# 10                                           Guinea-Bissau
# 15                                           Côte d’Ivoire
# 21                        Bolivia (Plurinational State of)
# 28                                                 Réunion
# 32                                                 Tokelau
# 35                                                   China
# 61                                United States of America
# 63                              Iran (Islamic Republic of)
# 104                     Venezuela (Bolivarian Republic of)
# 126      United Kingdom of Great Britain and Northern I...
# 132                             Taiwan (Province of China)
# 134                                               Viet Nam
# 185         China, Hong Kong Special Administrative Region
# 256                                         Azores Islands
# 352                                       French Polynesia
# 363                       Micronesia (Federated States of)
# 427                               Germany Federal Republic
# 531                                                Bahamas
# 630                                             Guadeloupe
# 804                  People's Democratic Republic of Yemen
# 835                                             Montserrat
# 836                                             Martinique
# 844                                  Sao Tome and Principe
# 1089                            German Democratic Republic
# 1195                                                  Niue
# 1230                              Turks and Caicos Islands
# 1406                          Netherlands (Kingdom of the)
# 1525                                          Saudi Arabia
# 2271                                     Serbia Montenegro
# 2652                             Wallis and Futuna Islands
# 2923            China, Macao Special Administrative Region
# 4215                                         French Guiana
# 5467                                        Canary Islands
# 5512                                         New Caledonia
# 5825                                    State of Palestine
# 5933                                              Anguilla
# 7348                                          Saint Helena
# 8566                              Northern Mariana Islands
# 12976                                              Mayotte
# 18084                                     Saint Barthélemy
# 18090                           Saint Martin (French Part)
# 18092                            Sint Maarten (Dutch part)
# 18331                                              Curaçao
# Name: Country, dtype: object

# %%
import re
import unicodedata
import pandas as pd

def normalize_country(name):
    if pd.isna(name):
        return None

    # Lowercase
    name = name.lower()

    # Remove accents
    name = unicodedata.normalize('NFKD', name)
    name = ''.join(c for c in name if not unicodedata.combining(c))

    # Replace separators with spaces
    name = re.sub(r'[-_/]', ' ', name)

    # Remove other punctuation
    name = re.sub(r'[^\w\s]', '', name)

    # Normalize whitespace
    name = re.sub(r'\s+', ' ', name).strip()

    return name

# %%
nd['country_norm'] = nd['Country'].apply(normalize_country)
cou['country_norm'] = cou['country'].apply(normalize_country)

not_in = nd[~nd['country_norm'].isin(cou['country_norm'])]
print(not_in['Country'].drop_duplicates())
# Out:
# 28                          Réunion
# 32                          Tokelau
# 256                  Azores Islands
# 352                French Polynesia
# 630                      Guadeloupe
# 835                      Montserrat
# 836                      Martinique
# 1195                           Niue
# 1230       Turks and Caicos Islands
# 2652      Wallis and Futuna Islands
# 4215                  French Guiana
# 5467                 Canary Islands
# 5512                  New Caledonia
# 5933                       Anguilla
# 7348                   Saint Helena
# 8566       Northern Mariana Islands
# 12976                       Mayotte
# 18084              Saint Barthélemy
# 18090    Saint Martin (French Part)
# 18092     Sint Maarten (Dutch part)
# 18331                       Curaçao
# Name: Country, dtype: object

# %%
print(len(not_in))
# Out:
# 4672

# %%
print(len(not_in_countries))
# Out:
# 4782

# %%
STOPWORDS = {'republic', 'of', 'the', 'and', 'is', 'democratic','arab','united','states','saint','islands','kingdom','new','peoples'}  # add more if needed

# Function to split into words and remove punctuation
def words_set(name):
    if pd.isna(name):
        return set()
    name = name.lower()
    name = re.sub(r'[^\w\s]', '', name)  # remove punctuation
    return set(name.split())

# Prepare sets
cou_words = cou['country'].apply(words_set)
not_in_words = not_in_countries['Country'].apply(words_set)

matches = []

for i, ni_words in enumerate(not_in_words):
    ni_name = not_in_countries.iloc[i]['Country']
    for j, c_words in enumerate(cou_words):
        c_name = cou.iloc[j]['country']
        shared = ni_words & c_words
        # ignore matches that are only stopwords
        filtered_shared = shared - STOPWORDS
        if filtered_shared:  # only keep if something meaningful remains
            matches.append((ni_name, c_name, filtered_shared))

# Convert to DataFrame
matches_df = pd.DataFrame(matches, columns=['NotIn', 'InCou', 'SharedWords'])

# %%
# Convert SharedWords set to a sorted tuple (or string)
matches_df['SharedWordsStr'] = matches_df['SharedWords'].apply(lambda x: ', '.join(sorted(x)))

# Drop duplicates based on all columns or specific columns
matches_df = matches_df.drop_duplicates(subset=['NotIn', 'InCou', 'SharedWordsStr'])

# %%
# Keep rows where SharedWordsStr is unique (appears only once)
unique_matches = matches_df[
    ~matches_df['SharedWordsStr'].duplicated(keep=False)
]
unique_matches
correction_map = dict(zip(unique_matches['NotIn'], unique_matches['InCou']))
correction_map
# Out:
# {'Gambia': 'THE GAMBIA',
#  'Côte d’Ivoire': "CÔTE D'IVOIRE",
#  'Bolivia (Plurinational State of)': 'BOLIVIA',
#  'Iran (Islamic Republic of)': 'ISLAMIC REPUBLIC OF IRAN',
#  'Venezuela (Bolivarian Republic of)': 'VENEZUELA',
#  'United Kingdom of Great Britain and Northern Ireland': 'IRELAND',
#  'China, Hong Kong Special Administrative Region': 'HONG KONG, CHINA',
#  'Micronesia (Federated States of)': 'FEDERATED STATES OF MICRONESIA',
#  'Bahamas': 'THE BAHAMAS',
#  'Saudi Arabia': 'KINGDOM OF SAUDI ARABIA',
#  'Serbia Montenegro': 'SERBIA AND MONTENEGRO',
#  'State of Palestine': 'PALESTINE'}

# %%
nd['Country'] = nd['Country'].apply(lambda x: correction_map.get(x, x))

# %%
nd['country_norm'] = nd['Country'].apply(normalize_country)
cou['country_norm'] = cou['country'].apply(normalize_country)

not_in = nd[~nd['country_norm'].isin(cou['country_norm'])]
print(not_in['Country'].drop_duplicates())
# Out:
# 9                               Yemen Arab Republic
# 28                                          Réunion
# 32                                          Tokelau
# 35                                            China
# 61                         United States of America
# 132                      Taiwan (Province of China)
# 134                                        Viet Nam
# 256                                  Azores Islands
# 352                                French Polynesia
# 427                        Germany Federal Republic
# 630                                      Guadeloupe
# 804           People's Democratic Republic of Yemen
# 835                                      Montserrat
# 836                                      Martinique
# 1089                     German Democratic Republic
# 1195                                           Niue
# 1230                       Turks and Caicos Islands
# 1406                   Netherlands (Kingdom of the)
# 2652                      Wallis and Futuna Islands
# 2923     China, Macao Special Administrative Region
# 4215                                  French Guiana
# 5467                                 Canary Islands
# 5512                                  New Caledonia
# 5933                                       Anguilla
# 7348                                   Saint Helena
# 8566                       Northern Mariana Islands
# 12976                                       Mayotte
# 18084                              Saint Barthélemy
# 18090                    Saint Martin (French Part)
# 18092                     Sint Maarten (Dutch part)
# 18331                                       Curaçao
# Name: Country, dtype: object

# %%
STOPWORDS = {'republic', 'of', 'the', 'and', 'is', 'democratic','arab','united','states','saint','islands','kingdom','new','peoples'}  # add more if needed

# Function to split into words and remove punctuation
def words_set(name):
    if pd.isna(name):
        return set()
    name = name.lower()
    name = re.sub(r'[^\w\s]', '', name)  # remove punctuation
    return set(name.split())

# Prepare sets
cou_words = cou['country'].apply(words_set)
not_in_words = not_in['Country'].apply(words_set)

matches = []

for i, ni_words in enumerate(not_in_words):
    ni_name = not_in.iloc[i]['Country']
    iso = not_in.iloc[i]['ISO']
    for j, c_words in enumerate(cou_words):
        c_name = cou.iloc[j]['country']
        noc = cou.iloc[j]['noc']
        shared = ni_words & c_words
        # ignore matches that are only stopwords
        filtered_shared = shared - STOPWORDS
        if filtered_shared:  # only keep if something meaningful remains
            matches.append((ni_name, c_name, filtered_shared,iso,noc))

# Convert to DataFrame
matches_df = pd.DataFrame(matches, columns=['NotIn', 'InCou', 'SharedWords','ISO','noc'])

# %%
# Convert SharedWords set to a sorted tuple (or string)
matches_df['SharedWordsStr'] = matches_df['SharedWords'].apply(lambda x: ', '.join(sorted(x)))

# Now drop duplicates based on all columns or specific columns
matches_df = matches_df.drop_duplicates(subset=['NotIn', 'InCou', 'SharedWordsStr','noc','ISO'])

# %%
matches_df
# Out:
#                                           NotIn                       InCou  \
# 0                           Yemen Arab Republic                 NORTH YEMEN
# 1                           Yemen Arab Republic                 SOUTH YEMEN
# 2                           Yemen Arab Republic                       YEMEN
# 3                                         China            HONG KONG, CHINA
# 4                                         China  PEOPLE'S REPUBLIC OF CHINA
# 33                   Taiwan (Province of China)            HONG KONG, CHINA
# 34                   Taiwan (Province of China)  PEOPLE'S REPUBLIC OF CHINA
# 73                     Germany Federal Republic                EAST GERMANY
# 74                     Germany Federal Republic                     GERMANY
# 75                     Germany Federal Republic                WEST GERMANY
# 153       People's Democratic Republic of Yemen                 NORTH YEMEN
# 154       People's Democratic Republic of Yemen                 SOUTH YEMEN
# 155       People's Democratic Republic of Yemen                       YEMEN
# 276                Netherlands (Kingdom of the)                 NETHERLANDS
# 277                Netherlands (Kingdom of the)        NETHERLANDS ANTILLES
# 563  China, Macao Special Administrative Region            HONG KONG, CHINA
# 564  China, Macao Special Administrative Region  PEOPLE'S REPUBLIC OF CHINA
#
#        SharedWords  ISO  noc SharedWordsStr
# 0          {yemen}  YMN  YAR          yemen
# 1          {yemen}  YMN  YMD          yemen
# 2          {yemen}  YMN  YEM          yemen
# 3          {china}  CHN  HKG          china
# 4          {china}  CHN  CHN          china
# 33         {china}  TWN  HKG          china
# 34         {china}  TWN  CHN          china
# 73       {germany}  DFR  GDR        germany
# 74       {germany}  DFR  GER        germany
# 75       {germany}  DFR  FRG        germany
# 153        {yemen}  YMD  YAR          yemen
# 154        {yemen}  YMD  YMD          yemen
# 155        {yemen}  YMD  YEM          yemen
# 276  {netherlands}  NLD  NED    netherlands
# 277  {netherlands}  NLD  AHO    netherlands
# 563        {china}  MAC  HKG          china
# 564        {china}  MAC  CHN          china

# %%
nd[nd["Country"]=="Yemen Arab Republic"]["ISO"]
# Out:
# 9       YMN
# 1061    YMN
# Name: ISO, dtype: object

# %%
nd[nd["Country"]=="People's Democratic Republic of Yemen"]["ISO"]
# Out:
# 804    YMD
# Name: ISO, dtype: object

# %%
CANONICAL_COUNTRY_MAP_COU = {
    # Yemen
    "NORTH YEMEN": "YEMEN",
    "SOUTH YEMEN": "YEMEN",

    # Germany
    "EAST GERMANY": "GERMANY",
    "WEST GERMANY": "GERMANY",
    "germany":"GERMANY",

    # Vietnam
    "SOUTH VIETNAM": "VIETNAM",
    
}
CANONICAL_NOC_MAP_COU = {
    # Yemen
    "YAR": "YEM",
    "YMD": "YEM",

    # Germany
    "GDR": "GER",
    "FRG": "GER",

    # Vietnam
    "VNM": "VIE",
}

CANONICAL_COUNTRY_MAP_ND = {
    # Germany
    "Germany Federal Republic": "GERMANY",
    "German Democratic Republic": "GERMANY",
    
    # Yemen
    "Yemen Arab Republic": "YEMEN",
    "People's Democratic Republic of Yemen": "YEMEN",

    # China
    "Taiwan (Province of China)": "PEOPLE'S REPUBLIC OF CHINA",
    "China, Macao Special Administrative Region": "PEOPLE'S REPUBLIC OF CHINA",
    "China": "PEOPLE'S REPUBLIC OF CHINA",

    # Netherlands
    "Netherlands (Kingdom of the)": "NETHERLANDS",

    
    # USA
    "United States of America": "UNITED STATES",

    # Vietnam
    "Viet Nam": "VIETNAM",

    #Guineau bissau
    "Guinea-Bissau":"GUINEA BISSAU",

    
    
}
CANONICAL_ISO_MAP_ND = {
    # Yemen
    "YMN": "YEM",
    "YMD": "YEM",

    # China
    "TWN": "CHN",
    "MAC": "CHN",
}

# %%
test=staging = Path("../test/cleaned")
matches_df.to_csv(test / "test.csv", index=False)

# %%
bio = pd.read_csv(staging /"Olympic_Athlete_Bio.csv")
res = pd.read_csv(staging /"Olympic_Athlete_Event_Results.csv")

# %%
bio['country_noc'] = bio['country_noc'].replace(CANONICAL_NOC_MAP_COU)
res['country_noc'] = res['country_noc'].replace(CANONICAL_NOC_MAP_COU)

# %%
cou['noc'] = cou['noc'].replace(CANONICAL_NOC_MAP_COU)
cou['country'] = cou['country'].replace(CANONICAL_COUNTRY_MAP_COU)

# %%
nd['Country'] = nd['Country'].replace(CANONICAL_COUNTRY_MAP_ND)
nd['ISO'] = nd['ISO'].replace(CANONICAL_ISO_MAP_ND)

# %%
nd[nd['Country']=="Germany Federal Republic"]
# Out:
# Empty DataFrame
# Columns: [DisNo., Disaster Group, Disaster Subgroup, Disaster Type, Disaster Subtype, Event Name, ISO, Country, Subregion, Region, Location, Origin, Magnitude, Magnitude Scale, Latitude, Longitude, Start Date, End Date, country_norm]
# Index: []

# %%
nd['country_norm'] = nd['Country'].apply(normalize_country)
cou['country_norm'] = cou['country'].apply(normalize_country)

not_in = nd[~nd['country_norm'].isin(cou['country_norm'])]
print(not_in[['Country','ISO']].drop_duplicates())
# Out:
#                           Country  ISO
# 28                        Réunion  REU
# 32                        Tokelau  TKL
# 256                Azores Islands  AZO
# 352              French Polynesia  PYF
# 630                    Guadeloupe  GLP
# 835                    Montserrat  MSR
# 836                    Martinique  MTQ
# 1195                         Niue  NIU
# 1230     Turks and Caicos Islands  TCA
# 2652    Wallis and Futuna Islands  WLF
# 4215                French Guiana  GUF
# 5467               Canary Islands  SPI
# 5512                New Caledonia  NCL
# 5933                     Anguilla  AIA
# 7348                 Saint Helena  SHN
# 8566     Northern Mariana Islands  MNP
# 12976                     Mayotte  MYT
# 18084            Saint Barthélemy  BLM
# 18090  Saint Martin (French Part)  MAF
# 18092   Sint Maarten (Dutch part)  SXM
# 18331                     Curaçao  CUW

# %%
print(len(bio))
print(len(bio[bio['country_noc'].isin(cou['noc'])]))
print(len(res))
print(len(res[res['country_noc'].isin(cou['noc'])]))
# Out:
# 155861
# 155861
# 316834
# 316834

# %%
STOPWORDS = {'republic', 'of', 'the', 'and', 'is', 'democratic','arab','united','states','saint','islands','kingdom','new','peoples'}  # add more if needed

# Function to split into words and remove punctuation
def words_set(name):
    if pd.isna(name):
        return set()
    name = name.lower()
    name = re.sub(r'[^\w\s]', '', name)  # remove punctuation
    return set(name.split())

# Prepare sets
cou_words = cou['country'].apply(words_set)
not_in_words = not_in['Country'].apply(words_set)

matches = []

for i, ni_words in enumerate(not_in_words):
    ni_name = not_in.iloc[i]['Country']
    iso = not_in.iloc[i]['ISO']
    for j, c_words in enumerate(cou_words):
        c_name = cou.iloc[j]['country']
        noc = cou.iloc[j]['noc']
        shared = ni_words & c_words
        # ignore matches that are only stopwords
        filtered_shared = shared - STOPWORDS
        if filtered_shared:  # only keep if something meaningful remains
            matches.append((ni_name, c_name, filtered_shared,iso,noc))

# Convert to DataFrame
matches_df = pd.DataFrame(matches, columns=['NotIn', 'InCou', 'SharedWords','ISO','noc'])

# %%
# Convert SharedWords set to a sorted tuple (or string)
matches_df['SharedWordsStr'] = matches_df['SharedWords'].apply(lambda x: ', '.join(sorted(x)))

# Now drop duplicates based on all columns or specific columns
matches_df = matches_df.drop_duplicates(subset=['NotIn', 'InCou', 'SharedWordsStr','noc','ISO'])

# %%
matches_df
# Out:
# Empty DataFrame
# Columns: [NotIn, InCou, SharedWords, ISO, noc, SharedWordsStr]
# Index: []

# %%
print("NORTH YEMEN")
print(bio[bio["country_noc"]=="YAR"])
print("==========================================")
print(res[res["country_noc"]=="YAR"])
# Out:
# NORTH YEMEN
# Empty DataFrame
# Columns: [athlete_id, name, sex, country_noc]
# Index: []
# ==========================================
# Empty DataFrame
# Columns: [edition, edition_id, country_noc, sport, event, result_id, athlete_id, medal]
# Index: []

# %%
print("SOUTH YEMEN")
print(bio[bio["country_noc"]=="YMD"])
print("==========================================")
print(res[res["country_noc"]=="YMD"])
# Out:
# SOUTH YEMEN
# Empty DataFrame
# Columns: [athlete_id, name, sex, country_noc]
# Index: []
# ==========================================
# Empty DataFrame
# Columns: [edition, edition_id, country_noc, sport, event, result_id, athlete_id, medal]
# Index: []

# %%
print("YEMEN")
print(bio[bio["country_noc"]=="YEM"])
print("==========================================")
print(res[res["country_noc"]=="YEM"])
# Out:
# YEMEN
#         athlete_id                    name     sex country_noc
# 1619         79345      Farouk Ahmed Sayed    Male         YEM
# 2843         33393      Mansour Al-Soraihi    Male         YEM
# 7003        120747  Fatima Suleiman Dahman  Female         YEM
# 11125        33390        Salah Al-Humaidi    Male         YEM
# 11536       112818            Ali Khousrof    Male         YEM
# 12952       147605          Ahmed Al-Yaari    Male         YEM
# 15137       120748          Nabil Al-Garbi    Male         YEM
# 15426       115890    Abdulsalam Al-Gadabi    Male         YEM
# 19442       115321      Mohammed Al-Yafaee    Male         YEM
# 21979        79339        Mohamed Al-Saadi    Male         YEM
# 24594        34099          Mohamed Moslih    Male         YEM
# 28746        60836       Abdullah Al-Ghrbi    Male         YEM
# 29471        60837       Abdullah Al-Izani    Male         YEM
# 30757       120746        Tameem Al-Kubati    Male         YEM
# 31120        33939         Mohamed Kohsrof    Male         YEM
# 32092        79332        Awad Saleh Ahmed    Male         YEM
# 33904        89199          Hana Ali Saleh  Female         YEM
# 48927       922366           Ali Al-Gazali    Male         YEM
# 49567        34103          Yahia Mufarrih    Male         YEM
# 49733       114763           Waseelah Saad  Female         YEM
# 50027        89198      Basheer Al-Khewani    Male         YEM
# 50958       147604       Yasameen Al-Raimi  Female         YEM
# 51124       111976       Nashwan Al-Harazi    Male         YEM
# 51620        33391        Mohamed Al-Jalai    Male         YEM
# 54867         8866   Mohamed Mahfood Sayed    Male         YEM
# 64150        79343           Anwar Mohamed    Male         YEM
# 81545        79335          Abdul Al-Ghadi    Male         YEM
# 81660        79340         Saeed Basweidan    Male         YEM
# 92981        79334       Khalid Al-Estashi    Male         YEM
# 94301       147607       Mokhtar Al-Yamani    Male         YEM
# 97838       132239          Nuna Ba Matraf  Female         YEM
# 99520        79338       Anwar Mohamed Ali    Male         YEM
# 104131      147606             Ahmed Ayash    Male         YEM
# 106225       60838      Abdullah Al-Shamsi    Male         YEM
# 110624      102601       Fahmi Abdul Wahab    Male         YEM
# 114396       79337         Anwar Al-Harazi    Male         YEM
# 115040      103864            Mohamed Saad    Male         YEM
# 116361       79336            Ali Al-Ghadi    Male         YEM
# 119974       79333    Ehab Fuad Ahmed Nagi    Male         YEM
# 127994      136488             Zeyad Mater    Male         YEM
# 130878      923785     Hussein Salah Joaim    Male         YEM
# 137913      108193           Akram Al-Noor    Male         YEM
# 140478       33392         Ahmed Al-Shiekh    Male         YEM
# 141522      136487          Mohammed Rageh    Male         YEM
# 142333        8865      Ali Mohamed Jaffer    Male         YEM
# 142964       79341       Abdul Karim Daoud    Male         YEM
# 146526       79342       Sahim Saleh Mehdi    Male         YEM
# 151017       79344       Awad Salah Nasser    Male         YEM
# 151759      105670    Saeed Ali Al-Adhreai    Male         YEM
# ==========================================
#                      edition  edition_id country_noc                sport  \
# 88720   1984 Summer Olympics          21         YEM            Athletics
# 88721   1984 Summer Olympics          21         YEM            Athletics
# 88722   1984 Summer Olympics          21         YEM            Athletics
# 88723   1984 Summer Olympics          21         YEM            Athletics
# 88724   1988 Summer Olympics          22         YEM            Athletics
# 88725   1988 Summer Olympics          22         YEM            Athletics
# 88726   1988 Summer Olympics          22         YEM            Athletics
# 88727   1988 Summer Olympics          22         YEM            Athletics
# 88728   1988 Summer Olympics          22         YEM                 Judo
# 88729   1988 Summer Olympics          22         YEM                 Judo
# 88730   1988 Summer Olympics          22         YEM            Wrestling
# 88731   1988 Summer Olympics          22         YEM            Wrestling
# 129214  1988 Summer Olympics          22         YEM            Athletics
# 129215  1988 Summer Olympics          22         YEM            Athletics
# 129216  1988 Summer Olympics          22         YEM            Athletics
# 129217  1988 Summer Olympics          22         YEM               Boxing
# 129218  1988 Summer Olympics          22         YEM               Boxing
# 187440  1992 Summer Olympics          23         YEM            Athletics
# 187441  1992 Summer Olympics          23         YEM            Athletics
# 187442  1992 Summer Olympics          23         YEM            Athletics
# 187443  1992 Summer Olympics          23         YEM            Athletics
# 187444  1992 Summer Olympics          23         YEM                 Judo
# 187445  1992 Summer Olympics          23         YEM                 Judo
# 187446  1992 Summer Olympics          23         YEM                 Judo
# 187447  1992 Summer Olympics          23         YEM                 Judo
# 187448  1992 Summer Olympics          23         YEM                 Judo
# 187449  1996 Summer Olympics          24         YEM            Athletics
# 187450  1996 Summer Olympics          24         YEM            Athletics
# 187451  1996 Summer Olympics          24         YEM            Athletics
# 187452  1996 Summer Olympics          24         YEM             Swimming
# 187453  1996 Summer Olympics          24         YEM            Wrestling
# 187454  2000 Summer Olympics          25         YEM            Athletics
# 187455  2000 Summer Olympics          25         YEM            Athletics
# 187456  2004 Summer Olympics          26         YEM            Athletics
# 187457  2004 Summer Olympics          26         YEM             Swimming
# 187458  2004 Summer Olympics          26         YEM            Taekwondo
# 187459  2008 Summer Olympics          53         YEM  Artistic Gymnastics
# 187460  2008 Summer Olympics          53         YEM  Artistic Gymnastics
# 187461  2008 Summer Olympics          53         YEM  Artistic Gymnastics
# 187462  2008 Summer Olympics          53         YEM  Artistic Gymnastics
# 187463  2008 Summer Olympics          53         YEM            Athletics
# 187464  2008 Summer Olympics          53         YEM            Athletics
# 187465  2008 Summer Olympics          53         YEM                 Judo
# 187466  2008 Summer Olympics          53         YEM             Swimming
# 187467  2012 Summer Olympics          54         YEM            Athletics
# 187468  2012 Summer Olympics          54         YEM            Athletics
# 187469  2012 Summer Olympics          54         YEM                 Judo
# 187470  2012 Summer Olympics          54         YEM            Taekwondo
# 187471  2016 Summer Olympics          59         YEM            Athletics
# 187472  2016 Summer Olympics          59         YEM                 Judo
# 187473  2016 Summer Olympics          59         YEM             Swimming
# 187474  2020 Summer Olympics          61         YEM            Athletics
# 187475  2020 Summer Olympics          61         YEM                 Judo
# 187476  2020 Summer Olympics          61         YEM             Shooting
# 187477  2020 Summer Olympics          61         YEM             Swimming
# 187478  2020 Summer Olympics          61         YEM             Swimming
# 187479  2020 Summer Olympics          61         YEM             Swimming
#
#                                     event  result_id  athlete_id medal
# 88720                     800 metres, Men      62690       79335   NaN
# 88721                   1,500 metres, Men      62710       79335   NaN
# 88722                   5,000 metres, Men      62722       79336   NaN
# 88723                  10,000 metres, Men      62732       79336   NaN
# 88724                     800 metres, Men      63330      102601   NaN
# 88725                   1,500 metres, Men      63350       79332   NaN
# 88726                   5,000 metres, Men      63360       79337   NaN
# 88727                  10,000 metres, Men      63369       79341   NaN
# 88728              Extra-Lightweight, Men      16446       33939   NaN
# 88729                    Lightweight, Men      16571       34099   NaN
# 88730       Lightweight, Greco-Roman, Men     130475       60838   NaN
# 88731        Welterweight, Freestyle, Men     129931       60836   NaN
# 129214                    100 metres, Men      63261       79333   NaN
# 129215                    200 metres, Men      63287       79342   NaN
# 129216                  5,000 metres, Men      63360       79345   NaN
# 129217                     Flyweight, Men      25620        8866   NaN
# 129218                 Featherweight, Men      25725        8865   NaN
# 187440                    800 metres, Men      64016       79343   NaN
# 187441                  1,500 metres, Men      64031       79344   NaN
# 187442                  5,000 metres, Men      64041      923785   NaN
# 187443                 10,000 metres, Men      64048       79334   NaN
# 187444             Extra-Lightweight, Men      16840       33390   NaN
# 187445              Half-Lightweight, Men      16912       33393   NaN
# 187446                   Lightweight, Men      16988       33391   NaN
# 187447             Half-Middleweight, Men      17060       33392   NaN
# 187448                  Middleweight, Men      17130       34103   NaN
# 187449                    400 metres, Men      64676       79338   NaN
# 187450                    800 metres, Men      64695       79340   NaN
# 187451                      Marathon, Men      64735       79339   NaN
# 187452          100 metres Freestyle, Men       7983      922366   NaN
# 187453  Light-Flyweight, Greco-Roman, Men     132454       60837   NaN
# 187454                    400 metres, Men      65353       89198   NaN
# 187455                  200 metres, Women      65704       89199   NaN
# 187456                    400 metres, Men      66049      105670   NaN
# 187457           50 metres Freestyle, Men       8740      103864   NaN
# 187458                     Flyweight, Men      28227      108193   NaN
# 187459         Individual All-Around, Men     259958      111976   NaN
# 187460                Floor Exercise, Men     259964      111976   NaN
# 187461                   Horse Vault, Men     259967      111976   NaN
# 187462               Pommelled Horse, Men     259979      111976   NaN
# 187463                    800 metres, Men     257197      115321   NaN
# 187464                  100 metres, Women     257553      114763   NaN
# 187465             Extra-Lightweight, Men     260188      112818   NaN
# 187466           50 metres Freestyle, Men     261468      115890   NaN
# 187467                  1,500 metres, Men     302226      120748   NaN
# 187468                  100 metres, Women     302089      120747   NaN
# 187469             Extra-Lightweight, Men     316000      112818   NaN
# 187470                     Flyweight, Men     325000      120746   NaN
# 187471                  1,500 metres, Men     358624      136487   NaN
# 187472                   Lightweight, Men     354580      136488   NaN
# 187473        100 metres Butterfly, Women     357269      132239   NaN
# 187474                    400 metres, Men   19000394      147605   NaN
# 187475                   Lightweight, Men   18001004      147606   NaN
# 187476       Air Pistol, 10 metres, Women   18000743      147604   NaN
# 187477          100 metres Freestyle, Men   19000014      147607   NaN
# 187478          200 metres Freestyle, Men   19000028      147607   NaN
# 187479     100 metres Breaststroke, Women   19000261      132239   NaN

# %%
print("NORTH YEMEN")

# %%
staging = Path("../data/staging")
cou = pd.read_csv(staging /"Olympics_Country.csv")
nd = pd.read_csv(staging /"02_normalize_date.csv")

# %%
cou['noc'] = cou['noc'].replace(CANONICAL_NOC_MAP_COU)
cou['country'] = cou['country'].replace(CANONICAL_COUNTRY_MAP_COU)
nd['Country'] = nd['Country'].replace(CANONICAL_COUNTRY_MAP_ND)
nd['ISO'] = nd['ISO'].replace(CANONICAL_ISO_MAP_ND)

# %%
nd['country_norm'] = nd['Country'].apply(normalize_country)
cou['country_norm'] = cou['country'].apply(normalize_country)

not_in = nd[~nd['country_norm'].isin(cou['country_norm'])]
print(not_in[['Country','ISO']].drop_duplicates())
# Out:
#                           Country  ISO
# 28                        Réunion  REU
# 32                        Tokelau  TKL
# 256                Azores Islands  AZO
# 352              French Polynesia  PYF
# 630                    Guadeloupe  GLP
# 835                    Montserrat  MSR
# 836                    Martinique  MTQ
# 1195                         Niue  NIU
# 1230     Turks and Caicos Islands  TCA
# 2652    Wallis and Futuna Islands  WLF
# 4215                French Guiana  GUF
# 5467               Canary Islands  SPI
# 5512                New Caledonia  NCL
# 5933                     Anguilla  AIA
# 7348                 Saint Helena  SHN
# 8566     Northern Mariana Islands  MNP
# 12976                     Mayotte  MYT
# 18084            Saint Barthélemy  BLM
# 18090  Saint Martin (French Part)  MAF
# 18092   Sint Maarten (Dutch part)  SXM
# 18331                     Curaçao  CUW

# %%
STOPWORDS = {'republic', 'of', 'the', 'and', 'is', 'democratic','arab','united','states','saint','islands','kingdom','new','peoples'}  # add more if needed

# Function to split into words and remove punctuation
def words_set(name):
    if pd.isna(name):
        return set()
    name = name.lower()
    name = re.sub(r'[^\w\s]', '', name)  # remove punctuation
    return set(name.split())

# Prepare sets
cou_words = cou['country'].apply(words_set)
not_in_words = not_in['Country'].apply(words_set)

matches = []

for i, ni_words in enumerate(not_in_words):
    ni_name = not_in.iloc[i]['Country']
    iso = not_in.iloc[i]['ISO']
    for j, c_words in enumerate(cou_words):
        c_name = cou.iloc[j]['country']
        noc = cou.iloc[j]['noc']
        shared = ni_words & c_words
        # ignore matches that are only stopwords
        filtered_shared = shared - STOPWORDS
        if filtered_shared:  # only keep if something meaningful remains
            matches.append((ni_name, c_name, filtered_shared,iso,noc))

# Convert to DataFrame
matches_df = pd.DataFrame(matches, columns=['NotIn', 'InCou', 'SharedWords','ISO','noc'])

# %%
# Convert SharedWords set to a sorted tuple (or string)
matches_df['SharedWordsStr'] = matches_df['SharedWords'].apply(lambda x: ', '.join(sorted(x)))

# Now drop duplicates based on all columns or specific columns
matches_df = matches_df.drop_duplicates(subset=['NotIn', 'InCou', 'SharedWordsStr','noc','ISO'])

# %%
matches_df
# Out:
# Empty DataFrame
# Columns: [NotIn, InCou, SharedWords, ISO, noc, SharedWordsStr]
# Index: []

# %%
# Keep rows where SharedWordsStr is unique (appears only once)
unique_matches = matches_df[
    ~matches_df['SharedWordsStr'].duplicated(keep=False)
]
unique_matches
correction_map = dict(zip(unique_matches['NotIn'], unique_matches['InCou']))
correction_map
# Out:
# {'Gambia': 'THE GAMBIA',
#  'Bolivia (Plurinational State of)': 'BOLIVIA',
#  'Iran (Islamic Republic of)': 'ISLAMIC REPUBLIC OF IRAN',
#  'Venezuela (Bolivarian Republic of)': 'VENEZUELA',
#  'United Kingdom of Great Britain and Northern Ireland': 'IRELAND',
#  'China, Hong Kong Special Administrative Region': "PEOPLE'S REPUBLIC OF CHINA",
#  'Micronesia (Federated States of)': 'FEDERATED STATES OF MICRONESIA',
#  'Bahamas': 'THE BAHAMAS',
#  'Saudi Arabia': 'KINGDOM OF SAUDI ARABIA',
#  'Serbia Montenegro': 'SERBIA AND MONTENEGRO',
#  'State of Palestine': 'PALESTINE'}

# %%
nd['Country'] = nd['Country'].apply(lambda x: correction_map.get(x, x))

# %%
nd.isna().sum()
# Out:
# DisNo.                   0
# Disaster Group           0
# Disaster Subgroup        0
# Disaster Type            0
# Disaster Subtype         0
# Event Name           15340
# ISO                      0
# Country                  0
# Subregion                0
# Region                   0
# Location              1537
# Origin               17970
# Magnitude            18251
# Magnitude Scale       8906
# Latitude             20516
# Longitude            20516
# Start Date               0
# End Date                 0
# country_norm             0
# dtype: int64

# %%
len(cou)
# Out:
# 230

# %%
cou=cou.drop_duplicates()

# %%
import pandas as pd
from pathlib import Path
staging = Path("../data/staging")


cou = pd.read_csv(staging /"Olympics_Country.csv")
nd = pd.read_csv(staging /"02_normalize_date.csv")
bio = pd.read_csv(staging /"Olympic_Athlete_Bio.csv")
res = pd.read_csv(staging /"Olympic_Athlete_Event_Results.csv")

# %%
not_in_countries = nd[
    ~nd['Country'].str.lower().isin(cou['country'].str.lower())
]
len(not_in_countries['Country'].drop_duplicates())
# Out:
# 24

# %%
not_in_countries['Country'].drop_duplicates()
# Out:
# 10                    Guinea-Bissau
# 15                    Côte d’Ivoire
# 28                          Réunion
# 32                          Tokelau
# 256                  Azores Islands
# 352                French Polynesia
# 630                      Guadeloupe
# 835                      Montserrat
# 836                      Martinique
# 844           Sao Tome and Principe
# 1195                           Niue
# 1230       Turks and Caicos Islands
# 2652      Wallis and Futuna Islands
# 4215                  French Guiana
# 5467                 Canary Islands
# 5512                  New Caledonia
# 5933                       Anguilla
# 7348                   Saint Helena
# 8566       Northern Mariana Islands
# 12976                       Mayotte
# 18084              Saint Barthélemy
# 18090    Saint Martin (French Part)
# 18092     Sint Maarten (Dutch part)
# 18331                       Curaçao
# Name: Country, dtype: object

# %%
nd['country_norm'] = nd['Country'].apply(normalize_country)
not_in_countries['country_norm'] = not_in_countries['Country'].apply(normalize_country)
cou['country_norm'] = cou['country'].apply(normalize_country)

not_in = nd[~nd['country_norm'].isin(cou['country_norm'])]
is_now_in = not_in_countries[not_in_countries['country_norm'].isin(cou['country_norm'])]

print(is_now_in['Country'].drop_duplicates())
# Out:
# 10             Guinea-Bissau
# 15             Côte d’Ivoire
# 844    Sao Tome and Principe
# Name: Country, dtype: object
# /var/folders/v0/th4fvpks3d951p9h1jtmdhtm0000gn/T/ipykernel_27727/435927298.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_in_countries['country_norm'] = not_in_countries['Country'].apply(normalize_country)

# %%
STOPWORDS = {'republic', 'of', 'the', 'and', 'is', 'democratic','arab','united','states','saint','islands','kingdom','new','peoples'}  # add more if needed

# Function to split into words and remove punctuation
def words_set(name):
            
    name = normalize_country(name)
    return set(name.split())

# Prepare sets
cou_words = cou['country'].apply(words_set)
not_in_words = not_in_countries['Country'].apply(words_set)

matches = []

for i, ni_words in enumerate(not_in_words):
    ni_name = not_in_countries.iloc[i]['Country']
    iso = not_in_countries.iloc[i]['ISO']
    for j, c_words in enumerate(cou_words):
        c_name = cou.iloc[j]['country']
        noc = cou.iloc[j]['noc']
        shared = ni_words & c_words
        # ignore matches that are only stopwords
        filtered_shared = shared - STOPWORDS
        if filtered_shared:  # only keep if something meaningful remains
            matches.append((ni_name, c_name, filtered_shared,iso,noc))

# Convert to DataFrame
matches_df = pd.DataFrame(matches, columns=['NotIn', 'InCou', 'SharedWords','ISO','noc'])

# %%
# Convert SharedWords set to a sorted tuple (or string)
matches_df['SharedWordsStr'] = matches_df['SharedWords'].apply(lambda x: ', '.join(sorted(x)))

# Now drop duplicates based on all columns or specific columns
matches_df = matches_df.drop_duplicates(subset=['NotIn', 'InCou', 'SharedWordsStr','noc','ISO'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       4 # Now drop duplicates based on all columns or specific columns
#       5 matches_df = matches_df.drop_duplicates(subset=['NotIn', 'InCou', 'SharedWordsStr','noc','ISO'])
# ----> 6 matches_df.drop_duplicates()
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:6840, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6837 inplace = validate_bool_kwarg(inplace, "inplace")
#    6838 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6840 result = self[-self.duplicated(subset, keep=keep)]
#    6841 if ignore_index:
#    6842     result.index = default_index(len(result))
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:6980, in DataFrame.duplicated(self, subset, keep)
#    6978 else:
#    6979     vals = (col.values for name, col in self.items() if name in subset)
# -> 6980     labels, shape = map(list, zip(*map(f, vals)))
#    6982     ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
#    6983     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:6948, in DataFrame.duplicated.<locals>.f(vals)
#    6947 def f(vals) -> tuple[np.ndarray, int]:
# -> 6948     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6949     return labels.astype("i8", copy=False), len(shape)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)    807         verify=False,
#     808     )
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/algorithms.py:595, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     592 hash_klass, values = _get_hashtable_algo(values)
#     594 table = hash_klass(size_hint or len(values))
# --> 595 uniques, codes = table.factorize(
#     596     values,
#     597     na_sentinel=-1,
#     598     na_value=na_value,
#     599     mask=mask,
#     600     ignore_na=use_na_sentinel,
#     601 )
#     603 # re-cast e.g. i8->dt64/td64, uint8->bool
#     604 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:7293, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:7203, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'set'

# %%
 not_in_countries
# Out:
#               DisNo. Disaster Group Disaster Subgroup        Disaster Type  \
# 10     1987-0015-GNB        Natural        Biological          Infestation
# 15     1987-0040-CIV  Technological         Transport                  Air
# 28     1987-0060-REU        Natural    Meteorological                Storm
# 32     1987-0064-TKL        Natural    Meteorological                Storm
# 73     1987-0118-GNB        Natural    Meteorological                Storm
# ...              ...            ...               ...                  ...
# 22474  2025-0387-CIV        Natural      Hydrological  Mass movement (wet)
# 22506  2025-0438-CIV  Technological         Transport                 Road
# 22575  2025-0617-CIV  Technological         Transport                 Road
# 22636  2025-0776-CIV  Technological         Transport                Water
# 22649  2025-0812-AZO        Natural    Meteorological                Storm
#
#               Disaster Subtype         Event Name  ISO         Country  \
# 10     Grasshopper infestation        Grasshopper  GNB   Guinea-Bissau
# 15                         Air         Boeing 707  CIV   Côte d’Ivoire
# 28            Tropical cyclone                NaN  REU         Réunion
# 32             Storm (General)                NaN  TKL         Tokelau
# 73            Tropical cyclone                NaN  GNB   Guinea-Bissau
# ...                        ...                ...  ...             ...
# 22474          Landslide (wet)                NaN  CIV   Côte d’Ivoire
# 22506                     Road                NaN  CIV   Côte d’Ivoire
# 22575                     Road                NaN  CIV   Côte d’Ivoire
# 22636                    Water                NaN  CIV   Côte d’Ivoire
# 22649          Storm (General)  Storm 'Gabrielle'  AZO  Azores Islands
#
#                 Subregion   Region  \
# 10     Sub-Saharan Africa   Africa
# 15     Sub-Saharan Africa   Africa
# 28     Sub-Saharan Africa   Africa
# 32              Polynesia  Oceania
# 73     Sub-Saharan Africa   Africa
# ...                   ...      ...
# 22474  Sub-Saharan Africa   Africa
# 22506  Sub-Saharan Africa   Africa
# 22575  Sub-Saharan Africa   Africa
# 22636  Sub-Saharan Africa   Africa
# 22649     Southern Europe   Europe
#
#                                            Location      Origin  Magnitude  \
# 10                                              NaN         NaN        NaN
# 15                                     Near Abidjan         NaN        NaN
# 28                                      Saint Denis         NaN        NaN
# 32                  Fakaofo, Nukumono, Atafu Atolls         NaN        NaN
# 73                                          Tombali         NaN        NaN
# ...                                             ...         ...        ...
# 22474                              Abidjan district  Heavy rain        NaN
# 22506                                Near Agboville         NaN        NaN
# 22575                   Between Katiola and Niakara         NaN        NaN
# 22636                 On river Sassandra, near Buyo         NaN        NaN
# 22649  Terceira, Sao Jorge, Pico, Faial et Graciosa         NaN      154.0
#
#       Magnitude Scale  Latitude  Longitude  Start Date    End Date  \
# 10                NaN       NaN        NaN  1987-01-01  1987-01-01
# 15                NaN       NaN        NaN  1987-01-03  1987-01-03
# 28                Kph       NaN        NaN  1987-02-13  1987-02-13
# 32                Kph       NaN        NaN  1987-02-27  1987-02-27
# 73                Kph       NaN        NaN  1987-07-01  1987-07-01
# ...               ...       ...        ...         ...         ...
# 22474             NaN       NaN        NaN  2025-05-20  2025-05-21
# 22506             NaN       NaN        NaN  2025-06-14  2025-06-14
# 22575             NaN       NaN        NaN  2025-07-27  2025-07-28
# 22636             NaN       NaN        NaN  2025-09-05  2025-09-05
# 22649             Kph       NaN        NaN  2025-09-25  2025-09-27
#
#          country_norm
# 10      guinea bissau
# 15       cote divoire
# 28            reunion
# 32            tokelau
# 73      guinea bissau
# ...               ...
# 22474    cote divoire
# 22506    cote divoire
# 22575    cote divoire
# 22636    cote divoire
# 22649  azores islands
#
# [226 rows x 19 columns]

# %%
matches_df
# Out:
#                     NotIn                  InCou            SharedWords  ISO  \
# 0           Guinea-Bissau      EQUATORIAL GUINEA               {guinea}  GNB
# 1           Guinea-Bissau                 GUINEA               {guinea}  GNB
# 2           Guinea-Bissau          GUINEA BISSAU       {bissau, guinea}  GNB
# 3           Guinea-Bissau       PAPUA NEW GUINEA               {guinea}  GNB
# 4           Côte d’Ivoire          CÔTE D'IVOIRE        {cote, divoire}  CIV
# 17  Sao Tome and Principe  SÃO TOMÉ AND PRÍNCIPE  {sao, tome, principe}  STP
#
#     noc       SharedWordsStr
# 0   GEQ               guinea
# 1   GUI               guinea
# 2   GBS       bissau, guinea
# 3   PNG               guinea
# 4   CIV        cote, divoire
# 17  STP  principe, sao, tome

# %%
# Keep rows where SharedWordsStr is unique (appears only once)
unique_matches = matches_df[
    ~matches_df['SharedWordsStr'].duplicated(keep=False)
]
unique_matches
correction_map = dict(zip(unique_matches['NotIn'], unique_matches['InCou']))
correction_map
# Out:
# {'Guinea-Bissau': 'GUINEA BISSAU',
#  'Côte d’Ivoire': "CÔTE D'IVOIRE",
#  'Sao Tome and Principe': 'SÃO TOMÉ AND PRÍNCIPE'}

# %%
print(len(bio))
print(len(bio[bio['country_noc'].isin(cou['noc'])]))
print(len(res))
print(len(res[res['country_noc'].isin(cou['noc'])]))
# Out:
# 155861
# 155861
# 316834
# 316834

# %%
games = pd.read_csv(staging /"Olympics_Games.csv")
print(len(games))
print(len(games[games['country_noc'].isin(cou['noc'])]))
# Out:
# 56
# 55

# %%
games[~games['country_noc'].isin(cou['noc'])]
# Out:
#     edition_id country_noc competition_start_date competition_end_date
# 16          18         FRG             1972-08-26           1972-09-11

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import unicodedata
import json

# ============================
# 1. LOAD RAW DATA
# ============================
# Adjust paths to your docker/airflow layout
staging = Path("../data/staging")


games = pd.read_csv(staging /"Olympic_Athlete_Event_Results.csv")

games.isna().sum()
# Out:
# edition             0
# edition_id          0
# country_noc         0
# sport               0
# event               0
# result_id           0
# athlete_id          0
# medal          272147
# dtype: int64

# %%
games['medal'].unique()
# Out:
# array([nan, 'Bronze', 'Silver', 'Gold'], dtype=object)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import unicodedata
import json

# ============================
# 1. LOAD RAW DATA
# ============================
# Adjust paths to your docker/airflow layout
staging = Path("../data/landing")


res = pd.read_csv(staging /"Olympic_Athlete_Event_Results.csv")

res.isna().sum()
# Out:
# edition             0
# edition_id          0
# country_noc         0
# sport               0
# event               0
# result_id           0
# athlete             0
# athlete_id          0
# pos                 0
# medal          272147
# isTeamSport         0
# dtype: int64

# %%
len(res)
# Out:
# 316834

# %%
res.nunique()
# Out:
# edition            55
# edition_id         55
# country_noc       231
# sport             112
# event             964
# result_id        7397
# athlete        154213
# athlete_id     155867
# pos              2449
# medal               3
# isTeamSport         2
# dtype: int64

# %%
len(res.drop_duplicates())
# Out:
# 315626

# %%
res=res.drop_duplicates()

# %%
cols = ['athlete_id', 'edition','edition_id', 'sport', 'event','result_id','country_noc','medal']

duplicates = res[res.duplicated(subset=cols, keep=False)]
duplicates
# Out:
#                      edition  edition_id country_noc             sport  \
# 37884   1936 Summer Olympics          11         BEL  Art Competitions
# 37889   1936 Summer Olympics          11         BEL  Art Competitions
# 53895   1948 Summer Olympics          12         DEN  Art Competitions
# 53897   1948 Summer Olympics          12         DEN  Art Competitions
# 57474   1936 Summer Olympics          11         AUT  Art Competitions
# ...                      ...         ...         ...               ...
# 316829  2022 Winter Olympics          62         NED         Bobsleigh
# 316830  2022 Winter Olympics          62         SVK         Bobsleigh
# 316831  2022 Winter Olympics          62         KOR         Bobsleigh
# 316832  2022 Winter Olympics          62         JAM         Bobsleigh
# 316833  2022 Winter Olympics          62         UKR         Bobsleigh
#
#                              event  result_id                     athlete  \
# 37884    Sculpturing, Medals, Open     920057                Willy Kreitz
# 37889    Sculpturing, Medals, Open     920057                Willy Kreitz
# 53895   Sculpturing, Statues, Open     920073              Knud Nellemose
# 53897   Sculpturing, Statues, Open     920073              Knud Nellemose
# 57474   Sculpturing, Statues, Open     920056               Josef Humplik
# ...                            ...        ...                         ...
# 316829              Monobob, Women   19019671              Karlien Sleper
# 316830              Monobob, Women   19019671          Viktória Čerňanská
# 316831              Monobob, Women   19019671                  Kim Yu-Ran
# 316832              Monobob, Women   19019671  Jazmine Fenlator-Victorian
# 316833              Monobob, Women   19019671                Lidiya Hunko
#
#         athlete_id pos medal  isTeamSport
# 37884        88615  AC   NaN        False
# 37889        88615  HC   NaN        False
# 53895       920234  HM   NaN        False
# 53897       920234  AC   NaN        False
# 57474       920032  HM   NaN        False
# ...            ...  ..   ...          ...
# 316829      148662  16   NaN        False
# 316830      138683  17   NaN        False
# 316831      137542  18   NaN        False
# 316832      128682  19   NaN        False
# 316833      149047  20   NaN        False
#
# [134 rows x 11 columns]

# %%
bio[['name','sex','country_noc']].drop_duplicates()
# Out:
#                       name     sex country_noc
# 0            Ivanka Bonova  FEMALE         BUL
# 1        Nataliya Uryadova  FEMALE         RUS
# 2       Essa Ismail Rashed    MALE         QAT
# 3              Péter Boros    MALE         HUN
# 4           Rudolf Piowatý    MALE         TCH
# ...                    ...     ...         ...
# 155856         Todd Makler    MALE         USA
# 155857        Géza Hollósi    MALE         HUN
# 155858  József Keresztessy    MALE         HUN
# 155859    Alexander Thieme    MALE         GER
# 155860         Sunday Bada    MALE         NGR
#
# [154182 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import unicodedata
import json

# ============================
# 1. LOAD RAW DATA
# ============================
# Adjust paths to your docker/airflow layout
staging = Path("../data/staging")



res = pd.read_csv(staging /"02_normalize_date.csv")
nd.isna().sum()
# Out:
# DisNo.                   0
# Disaster Group           0
# Disaster Subgroup        0
# Disaster Type            0
# Disaster Subtype         0
# Event Name           15340
# ISO                      0
# Country                  0
# Subregion                0
# Region                   0
# Location              1537
# Origin               17970
# Magnitude            18251
# Magnitude Scale       8906
# Latitude             20516
# Longitude            20516
# Start Date               0
# End Date                 0
# dtype: int64

# %%
nd.nunique()
# Out:
# DisNo.               22710
# Disaster Group           2
# Disaster Subgroup        9
# Disaster Type           31
# Disaster Subtype        66
# Event Name            3118
# ISO                    227
# Country                226
# Subregion               17
# Region                   5
# Location             18470
# Origin                 870
# Magnitude             1863
# Magnitude Scale          6
# Latitude              1940
# Longitude             1935
# Start Date           10213
# End Date             10252
# dtype: int64

# %%
len(nd)
# Out:
# 22710

# %%
res = pd.read_csv(staging /"Olympic_Athlete_Event_Results.csv")

# %%
res.isna().sum()
# Out:
# edition             0
# edition_id          0
# country_noc         0
# sport               0
# event               0
# result_id           0
# athlete_id          0
# medal          270876
# dtype: int64

# %%
len(res['medal'].notnull())
# Out:
# 315559

# %%
res[res['medal'].notnull()]
# Out:
#                      edition  edition_id country_noc          sport  \
# 20      1908 Summer Olympics           5         ANZ      Athletics
# 30      1908 Summer Olympics           5         ANZ         Boxing
# 32      1908 Summer Olympics           5         ANZ          Rugby
# 33      1908 Summer Olympics           5         ANZ          Rugby
# 34      1908 Summer Olympics           5         ANZ          Rugby
# ...                      ...         ...         ...            ...
# 315546  2022 Winter Olympics          62         USA  Speed Skating
# 315547  2022 Winter Olympics          62         USA  Speed Skating
# 315548  2022 Winter Olympics          62         USA  Speed Skating
# 315549  2022 Winter Olympics          62         USA  Speed Skating
# 315552  2022 Winter Olympics          62         USA  Speed Skating
#
#                               event  result_id  athlete_id   medal
# 20      3,500 metres Race Walk, Men      56421       64719  Bronze
# 30                Middleweight, Men      21263       45153  Silver
# 32                       Rugby, Men      31505       11237    Gold
# 33                       Rugby, Men      31505       11239    Gold
# 34                       Rugby, Men      31505       11240    Gold
# ...                             ...        ...         ...     ...
# 315546   Team Pursuit (8 laps), Men   19020410      149164  Bronze
# 315547   Team Pursuit (8 laps), Men   19020410      128783  Bronze
# 315548   Team Pursuit (8 laps), Men   19020410      128784  Bronze
# 315549            500 metres, Women   19020424      138378    Gold
# 315552          1,000 metres, Women   19020425      128778  Bronze
#
# [44683 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import unicodedata
import json

# ============================
# 1. LOAD RAW DATA
# ============================
# Adjust paths to your docker/airflow layout
staging = Path("../data/staging")



nd = pd.read_csv(staging /"02_normalize_date.csv")

nd.isna().sum()
# Out:
# DisNo.                   0
# Disaster Group           0
# Disaster Subgroup        0
# Disaster Type            0
# Disaster Subtype         0
# Event Name           15340
# ISO                      0
# Country                  0
# Subregion                0
# Region                   0
# Location              1537
# Origin               17970
# Magnitude            18251
# Magnitude Scale       8906
# Latitude             20516
# Longitude            20516
# Start Date               0
# End Date                 0
# dtype: int64

# %%
nd.nunique()
# Out:
# DisNo.               22710
# Disaster Group           2
# Disaster Subgroup        9
# Disaster Type           31
# Disaster Subtype        66
# Event Name            3118
# ISO                    227
# Country                226
# Subregion               17
# Region                   5
# Location             18470
# Origin                 870
# Magnitude             1863
# Magnitude Scale          6
# Latitude              1940
# Longitude             1935
# Start Date           10213
# End Date             10252
# dtype: int64

# %%
len(nd)
# Out:
# 22710

# %%
nd['Magnitude Scale'].drop_duplicates()
# Out:
# 0                  Km2
# 1                  NaN
# 16                 Kph
# 23          Vaccinated
# 26    Moment Magnitude
# 35                  m3
# 65                  °C
# Name: Magnitude Scale, dtype: object

# %%
nd[nd['Magnitude Scale']=='Moment Magnitude']
# Out:
#               DisNo. Disaster Group Disaster Subgroup Disaster Type  \
# 26     1987-0058-PNG        Natural       Geophysical    Earthquake
# 34     1987-0068-NZL        Natural       Geophysical    Earthquake
# 36     1987-0070-ECU        Natural       Geophysical    Earthquake
# 48     1987-0086-IDN        Natural       Geophysical    Earthquake
# 63     1987-0101-IRN        Natural       Geophysical    Earthquake
# ...              ...            ...               ...           ...
# 22663  2025-0844-PHL        Natural       Geophysical    Earthquake
# 22672  2025-0867-ETH        Natural       Geophysical    Earthquake
# 22674  2025-0870-PHL        Natural       Geophysical    Earthquake
# 22681  2025-0882-IDN        Natural       Geophysical    Earthquake
# 22703  2025-0932-AFG        Natural       Geophysical    Earthquake
#
#       Disaster Subtype Event Name  ISO                   Country  \
# 26     Ground movement        NaN  PNG          Papua New Guinea
# 34     Ground movement        NaN  NZL               New Zealand
# 36     Ground movement        NaN  ECU                   Ecuador
# 48     Ground movement        NaN  IDN                 Indonesia
# 63     Ground movement        NaN  IRN  ISLAMIC REPUBLIC OF IRAN
# ...                ...        ...  ...                       ...
# 22663  Ground movement        NaN  PHL               Philippines
# 22672  Ground movement        NaN  ETH                  Ethiopia
# 22674  Ground movement        NaN  PHL               Philippines
# 22681  Ground movement        NaN  IDN                 Indonesia
# 22703  Ground movement        NaN  AFG               Afghanistan
#
#                              Subregion    Region  \
# 26                           Melanesia   Oceania
# 34           Australia and New Zealand   Oceania
# 36     Latin America and the Caribbean  Americas
# 48                  South-eastern Asia      Asia
# 63                       Southern Asia      Asia
# ...                                ...       ...
# 22663               South-eastern Asia      Asia
# 22672               Sub-Saharan Africa    Africa
# 22674               South-eastern Asia      Asia
# 22681               South-eastern Asia      Asia
# 22703                    Southern Asia      Asia
#
#                                              Location Origin  Magnitude  \
# 26      Umboi Isl., Finschafen area of Huon peninsula    NaN        7.4
# 34                          Edgecumbe (Bay of Plenty)    NaN        6.5
# 36          Carchi, Imbabura, Pastaza, Napo provinces    NaN        7.2
# 48                           Tarutung (North Sumatra)    NaN        6.4
# 63     NAHAVAND-HAMADEN-TUYSARKAN (Southwest Teheran)    NaN        4.6
# ...                                               ...    ...        ...
# 22663                                Bogo (Cebu Isl.)    NaN        6.9
# 22672                         Afar and Tigray regions    NaN        5.7
# 22674  Davao Oriental, Davao de Oro (Mindanao Island)    NaN        6.7
# 22681                            Sarmi region (Papua)    NaN        6.5
# 22703       Kholm (Samangan province); Balkh province    NaN        6.3
#
#         Magnitude Scale  Latitude  Longitude  Start Date    End Date
# 26     Moment Magnitude    -6.088    147.689  1987-02-09  1987-02-09
# 34     Moment Magnitude   -37.965    176.765  1987-03-02  1987-03-02
# 36     Moment Magnitude     0.151    -77.785  1987-03-05  1987-03-05
# 48     Moment Magnitude     2.244     98.866  1987-04-26  1987-04-26
# 63     Moment Magnitude    34.076     48.266  1987-05-29  1987-05-29
# ...                 ...       ...        ...         ...         ...
# 22663  Moment Magnitude    11.136    124.127  2025-10-01  2025-10-01
# 22672  Moment Magnitude       NaN        NaN  2025-10-11  2025-10-11
# 22674  Moment Magnitude     7.172    126.755  2025-10-10  2025-10-10
# 22681  Moment Magnitude    -2.168    138.938  2025-10-16  2025-10-16
# 22703  Moment Magnitude    36.589     67.484  2025-11-02  2025-11-02
#
# [1005 rows x 18 columns]
